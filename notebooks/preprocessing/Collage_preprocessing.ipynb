# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../")

# %%
from pathlib import Path

# %%
data_root = Path("../../data/")

# %% [markdown]
# ## Transform Multiclass Masks into Binary Masks

# %% [markdown]
# Changelog:
# 1. 2D -> 3D
# 2. Put mask into different class subdirectories, while leaving images unchanged.
# 3. distal_tubules(3) and proximal_tubules(5) merged to "Tubules"(3)
# 4. Path changes: files are saved in train/test directories separately, so necessary changes should be applied to the code.
# 5. Remove Arteriole subclass

# %%
import pandas as pd
from ml_core.utils.annotations import *
from PIL import Image
from pathlib import Path
from matplotlib.pyplot import imshow

# %%
label_info = pd.DataFrame({
    "label": [0, 1, 2, 3, 4],
    "label_name": ["Background", "Arteriole", "Artery", "Tubules", "Glomerulus"],
    "color": ["#000000", "#ffffff", "#ffffff", "#ffffff", "#ffffff"]
})

# %%
def save_mask_to_subdir(label_info, mask_path, output_dir):

    mask = np.array(Image.open(mask_path))
    mask[mask == 5] = 3 # tubules class merge
    
    for row in label_info.itertuples():
        label, label_name = row.label, row.label_name
        if label <= 0:
            continue # skip the background and omitted classes (< 0)
        
        subdir = output_dir / Path(f"{label_name}/")
        subdir.mkdir(exist_ok=True, parents=True)
        
        binary_mask = np.array(mask == label, dtype=np.uint8)
        
        if not np.any(binary_mask):
            # not found any pixel belong to this class
            # just skip it
            continue

        assert np.all(np.unique(binary_mask) == np.array([0,1], dtype=np.uint8)), \
                print(f"For class {label_name}, unique labels detected: {list(np.unique(binary_mask))}")
        
        single_class_label_info = pd.DataFrame({
            "label": [1],
            "label_name":[label_name],
            "color": ["#ffffff"]
        })
        
        mask_3d = generate_colorful_mask(binary_mask, single_class_label_info)
        
        Image.fromarray(mask_3d).save(subdir / mask_path.name)
    
    print(f"Finish generating class-level masks for {mask_path.name}.")

# %%
for dataset_type in ["train", "val"]:
    raw_data_root = Path(f"../../data/Collage/ROI_data/{dataset_type}/Raw/")
    output_dir = Path(f"../../data/Collage/ROI_data/{dataset_type}/")
    print(f"Dealing with {dataset_type} dataset ...")
    for mask_path in sorted(raw_data_root.glob("mask_*.png")):
        save_mask_to_subdir(label_info, mask_path, output_dir)
# Out:
# Dealing with train dataset ...
# Finish generating class-level masks for mask_train_1.png.
# Finish generating class-level masks for mask_train_10.png.
# Finish generating class-level masks for mask_train_100.png.
# Finish generating class-level masks for mask_train_11.png.
# Finish generating class-level masks for mask_train_12.png.
# Finish generating class-level masks for mask_train_13.png.
# Finish generating class-level masks for mask_train_14.png.
# Finish generating class-level masks for mask_train_15.png.
# Finish generating class-level masks for mask_train_16.png.
# Finish generating class-level masks for mask_train_17.png.
# Finish generating class-level masks for mask_train_18.png.
# Finish generating class-level masks for mask_train_19.png.
# Finish generating class-level masks for mask_train_2.png.
# Finish generating class-level masks for mask_train_20.png.
# Finish generating class-level masks for mask_train_200.png.
# Finish generating class-level masks for mask_train_201.png.
# Finish generating class-level masks for mask_train_202.png.
# Finish generating class-level masks for mask_train_203.png.
# Finish generating class-level masks for mask_train_204.png.
# Finish generating class-level masks for mask_train_205.png.
# Finish generating class-level masks for mask_train_206.png.
# Finish generating class-level masks for mask_train_207.png.
# Finish generating class-level masks for mask_train_208.png.
# Finish generating class-level masks for mask_train_209.png.
# Finish generating class-level masks for mask_train_21.png.
# Finish generating class-level masks for mask_train_210.png.
# Finish generating class-level masks for mask_train_211.png.
# Finish generating class-level masks for mask_train_212.png.
# Finish generating class-level masks for mask_train_213.png.
# Finish generating class-level masks for mask_train_214.png.
# Finish generating class-level masks for mask_train_215.png.
# Finish generating class-level masks for mask_train_216.png.
# Finish generating class-level masks for mask_train_217.png.
# Finish generating class-level masks for mask_train_218.png.
# Finish generating class-level masks for mask_train_219.png.
# Finish generating class-level masks for mask_train_22.png.
# Finish generating class-level masks for mask_train_220.png.
# Finish generating class-level masks for mask_train_221.png.
# Finish generating class-level masks for mask_train_222.png.
# Finish generating class-level masks for mask_train_223.png.
# Finish generating class-level masks for mask_train_224.png.
# Finish generating class-level masks for mask_train_225.png.
# Finish generating class-level masks for mask_train_226.png.
# Finish generating class-level masks for mask_train_227.png.
# Finish generating class-level masks for mask_train_228.png.
# Finish generating class-level masks for mask_train_229.png.
# Finish generating class-level masks for mask_train_23.png.
# Finish generating class-level masks for mask_train_230.png.
# Finish generating class-level masks for mask_train_231.png.
# Finish generating class-level masks for mask_train_232.png.
# Finish generating class-level masks for mask_train_233.png.
# Finish generating class-level masks for mask_train_234.png.
# Finish generating class-level masks for mask_train_235.png.
# Finish generating class-level masks for mask_train_236.png.
# Finish generating class-level masks for mask_train_237.png.
# Finish generating class-level masks for mask_train_238.png.
# Finish generating class-level masks for mask_train_239.png.
# Finish generating class-level masks for mask_train_24.png.
# Finish generating class-level masks for mask_train_240.png.
# Finish generating class-level masks for mask_train_241.png.
# Finish generating class-level masks for mask_train_242.png.
# Finish generating class-level masks for mask_train_243.png.
# Finish generating class-level masks for mask_train_244.png.
# Finish generating class-level masks for mask_train_245.png.
# Finish generating class-level masks for mask_train_246.png.
# Finish generating class-level masks for mask_train_247.png.
# Finish generating class-level masks for mask_train_248.png.
# Finish generating class-level masks for mask_train_249.png.
# Finish generating class-level masks for mask_train_25.png.
# Finish generating class-level masks for mask_train_250.png.
# Finish generating class-level masks for mask_train_251.png.
# Finish generating class-level masks for mask_train_252.png.
# Finish generating class-level masks for mask_train_253.png.
# Finish generating class-level masks for mask_train_254.png.
# Finish generating class-level masks for mask_train_255.png.
# Finish generating class-level masks for mask_train_256.png.
# Finish generating class-level masks for mask_train_257.png.
# Finish generating class-level masks for mask_train_258.png.
# Finish generating class-level masks for mask_train_259.png.
# Finish generating class-level masks for mask_train_26.png.
# Finish generating class-level masks for mask_train_260.png.
# Finish generating class-level masks for mask_train_261.png.
# Finish generating class-level masks for mask_train_262.png.
# Finish generating class-level masks for mask_train_263.png.
# Finish generating class-level masks for mask_train_264.png.
# Finish generating class-level masks for mask_train_265.png.
# Finish generating class-level masks for mask_train_266.png.
# Finish generating class-level masks for mask_train_267.png.
# Finish generating class-level masks for mask_train_268.png.
# Finish generating class-level masks for mask_train_269.png.
# Finish generating class-level masks for mask_train_27.png.
# Finish generating class-level masks for mask_train_270.png.
# Finish generating class-level masks for mask_train_271.png.
# Finish generating class-level masks for mask_train_272.png.
# Finish generating class-level masks for mask_train_273.png.
# Finish generating class-level masks for mask_train_274.png.
# Finish generating class-level masks for mask_train_275.png.
# Finish generating class-level masks for mask_train_276.png.
# Finish generating class-level masks for mask_train_277.png.
# Finish generating class-level masks for mask_train_278.png.
# Finish generating class-level masks for mask_train_279.png.
# Finish generating class-level masks for mask_train_28.png.
# Finish generating class-level masks for mask_train_280.png.
# Finish generating class-level masks for mask_train_281.png.
# Finish generating class-level masks for mask_train_282.png.
# Finish generating class-level masks for mask_train_283.png.
# Finish generating class-level masks for mask_train_284.png.
# Finish generating class-level masks for mask_train_285.png.
# Finish generating class-level masks for mask_train_286.png.
# Finish generating class-level masks for mask_train_287.png.
# Finish generating class-level masks for mask_train_288.png.
# Finish generating class-level masks for mask_train_289.png.
# Finish generating class-level masks for mask_train_29.png.
# Finish generating class-level masks for mask_train_290.png.
# Finish generating class-level masks for mask_train_291.png.
# Finish generating class-level masks for mask_train_292.png.
# Finish generating class-level masks for mask_train_293.png.
# Finish generating class-level masks for mask_train_294.png.
# Finish generating class-level masks for mask_train_295.png.
# Finish generating class-level masks for mask_train_296.png.
# Finish generating class-level masks for mask_train_297.png.
# Finish generating class-level masks for mask_train_298.png.
# Finish generating class-level masks for mask_train_299.png.
# Finish generating class-level masks for mask_train_3.png.
# Finish generating class-level masks for mask_train_30.png.
# Finish generating class-level masks for mask_train_300.png.
# Finish generating class-level masks for mask_train_301.png.
# Finish generating class-level masks for mask_train_302.png.
# Finish generating class-level masks for mask_train_303.png.
# Finish generating class-level masks for mask_train_304.png.
# Finish generating class-level masks for mask_train_305.png.
# Finish generating class-level masks for mask_train_306.png.
# Finish generating class-level masks for mask_train_307.png.
# Finish generating class-level masks for mask_train_31.png.
# Finish generating class-level masks for mask_train_32.png.
# Finish generating class-level masks for mask_train_33.png.
# Finish generating class-level masks for mask_train_34.png.
# Finish generating class-level masks for mask_train_35.png.
# Finish generating class-level masks for mask_train_350.png.
# Finish generating class-level masks for mask_train_351.png.
# Finish generating class-level masks for mask_train_352.png.
# Finish generating class-level masks for mask_train_353.png.
# Finish generating class-level masks for mask_train_354.png.
# Finish generating class-level masks for mask_train_355.png.
# Finish generating class-level masks for mask_train_356.png.
# Finish generating class-level masks for mask_train_357.png.
# Finish generating class-level masks for mask_train_358.png.
# Finish generating class-level masks for mask_train_36.png.
# Finish generating class-level masks for mask_train_37.png.
# Finish generating class-level masks for mask_train_38.png.
# Finish generating class-level masks for mask_train_39.png.
# Finish generating class-level masks for mask_train_4.png.
# Finish generating class-level masks for mask_train_40.png.
# Finish generating class-level masks for mask_train_41.png.
# Finish generating class-level masks for mask_train_42.png.
# Finish generating class-level masks for mask_train_43.png.
# Finish generating class-level masks for mask_train_44.png.
# Finish generating class-level masks for mask_train_45.png.
# Finish generating class-level masks for mask_train_46.png.
# Finish generating class-level masks for mask_train_47.png.
# Finish generating class-level masks for mask_train_48.png.
# Finish generating class-level masks for mask_train_49.png.
# Finish generating class-level masks for mask_train_5.png.
# Finish generating class-level masks for mask_train_50.png.
# Finish generating class-level masks for mask_train_51.png.
# Finish generating class-level masks for mask_train_52.png.
# Finish generating class-level masks for mask_train_53.png.
# Finish generating class-level masks for mask_train_54.png.
# Finish generating class-level masks for mask_train_55.png.
# Finish generating class-level masks for mask_train_56.png.
# Finish generating class-level masks for mask_train_57.png.
# Finish generating class-level masks for mask_train_58.png.
# Finish generating class-level masks for mask_train_59.png.
# Finish generating class-level masks for mask_train_6.png.
# Finish generating class-level masks for mask_train_60.png.
# Finish generating class-level masks for mask_train_61.png.
# Finish generating class-level masks for mask_train_62.png.
# Finish generating class-level masks for mask_train_63.png.
# Finish generating class-level masks for mask_train_64.png.
# Finish generating class-level masks for mask_train_65.png.
# Finish generating class-level masks for mask_train_66.png.
# Finish generating class-level masks for mask_train_67.png.
# Finish generating class-level masks for mask_train_68.png.
# Finish generating class-level masks for mask_train_69.png.
# Finish generating class-level masks for mask_train_7.png.
# Finish generating class-level masks for mask_train_70.png.
# Finish generating class-level masks for mask_train_71.png.
# Finish generating class-level masks for mask_train_72.png.
# Finish generating class-level masks for mask_train_73.png.
# Finish generating class-level masks for mask_train_74.png.
# Finish generating class-level masks for mask_train_75.png.
# Finish generating class-level masks for mask_train_76.png.
# Finish generating class-level masks for mask_train_77.png.
# Finish generating class-level masks for mask_train_78.png.
# Finish generating class-level masks for mask_train_79.png.
# Finish generating class-level masks for mask_train_8.png.
# Finish generating class-level masks for mask_train_80.png.
# Finish generating class-level masks for mask_train_81.png.
# Finish generating class-level masks for mask_train_82.png.
# Finish generating class-level masks for mask_train_83.png.
# Finish generating class-level masks for mask_train_84.png.
# Finish generating class-level masks for mask_train_85.png.
# Finish generating class-level masks for mask_train_86.png.
# Finish generating class-level masks for mask_train_87.png.
# Finish generating class-level masks for mask_train_88.png.
# Finish generating class-level masks for mask_train_89.png.
# Finish generating class-level masks for mask_train_9.png.
# Finish generating class-level masks for mask_train_90.png.
# Finish generating class-level masks for mask_train_91.png.
# Finish generating class-level masks for mask_train_92.png.
# Finish generating class-level masks for mask_train_93.png.
# Finish generating class-level masks for mask_train_94.png.
# Finish generating class-level masks for mask_train_95.png.
# Finish generating class-level masks for mask_train_96.png.
# Finish generating class-level masks for mask_train_97.png.
# Finish generating class-level masks for mask_train_98.png.
# Finish generating class-level masks for mask_train_99.png.
# Dealing with val dataset ...
# Finish generating class-level masks for mask_validation_1.png.
# Finish generating class-level masks for mask_validation_10.png.
# Finish generating class-level masks for mask_validation_100.png.
# Finish generating class-level masks for mask_validation_101.png.
# Finish generating class-level masks for mask_validation_102.png.
# Finish generating class-level masks for mask_validation_103.png.
# Finish generating class-level masks for mask_validation_104.png.
# Finish generating class-level masks for mask_validation_105.png.
# Finish generating class-level masks for mask_validation_106.png.
# Finish generating class-level masks for mask_validation_107.png.
# Finish generating class-level masks for mask_validation_108.png.
# Finish generating class-level masks for mask_validation_109.png.
# Finish generating class-level masks for mask_validation_11.png.
# Finish generating class-level masks for mask_validation_110.png.
# Finish generating class-level masks for mask_validation_111.png.
# Finish generating class-level masks for mask_validation_112.png.
# Finish generating class-level masks for mask_validation_113.png.
# Finish generating class-level masks for mask_validation_114.png.
# Finish generating class-level masks for mask_validation_115.png.
# Finish generating class-level masks for mask_validation_116.png.
# Finish generating class-level masks for mask_validation_117.png.
# Finish generating class-level masks for mask_validation_12.png.
# Finish generating class-level masks for mask_validation_13.png.
# Finish generating class-level masks for mask_validation_14.png.
# Finish generating class-level masks for mask_validation_15.png.
# Finish generating class-level masks for mask_validation_16.png.
# Finish generating class-level masks for mask_validation_17.png.
# Finish generating class-level masks for mask_validation_18.png.
# Finish generating class-level masks for mask_validation_19.png.
# Finish generating class-level masks for mask_validation_2.png.
# Finish generating class-level masks for mask_validation_20.png.
# Finish generating class-level masks for mask_validation_21.png.
# Finish generating class-level masks for mask_validation_22.png.
# Finish generating class-level masks for mask_validation_23.png.
# Finish generating class-level masks for mask_validation_24.png.
# Finish generating class-level masks for mask_validation_25.png.
# Finish generating class-level masks for mask_validation_26.png.
# Finish generating class-level masks for mask_validation_27.png.
# Finish generating class-level masks for mask_validation_28.png.
# Finish generating class-level masks for mask_validation_29.png.
# Finish generating class-level masks for mask_validation_3.png.
# Finish generating class-level masks for mask_validation_30.png.
# Finish generating class-level masks for mask_validation_31.png.
# Finish generating class-level masks for mask_validation_32.png.
# Finish generating class-level masks for mask_validation_33.png.
# Finish generating class-level masks for mask_validation_34.png.
# Finish generating class-level masks for mask_validation_35.png.
# Finish generating class-level masks for mask_validation_36.png.
# Finish generating class-level masks for mask_validation_37.png.
# Finish generating class-level masks for mask_validation_38.png.
# Finish generating class-level masks for mask_validation_39.png.
# Finish generating class-level masks for mask_validation_4.png.
# Finish generating class-level masks for mask_validation_40.png.
# Finish generating class-level masks for mask_validation_41.png.
# Finish generating class-level masks for mask_validation_42.png.
# Finish generating class-level masks for mask_validation_43.png.
# Finish generating class-level masks for mask_validation_44.png.
# Finish generating class-level masks for mask_validation_45.png.
# Finish generating class-level masks for mask_validation_46.png.
# Finish generating class-level masks for mask_validation_47.png.
# Finish generating class-level masks for mask_validation_48.png.
# Finish generating class-level masks for mask_validation_49.png.
# Finish generating class-level masks for mask_validation_5.png.
# Finish generating class-level masks for mask_validation_50.png.
# Finish generating class-level masks for mask_validation_51.png.
# Finish generating class-level masks for mask_validation_52.png.
# Finish generating class-level masks for mask_validation_53.png.
# Finish generating class-level masks for mask_validation_54.png.
# Finish generating class-level masks for mask_validation_55.png.
# Finish generating class-level masks for mask_validation_56.png.
# Finish generating class-level masks for mask_validation_57.png.
# Finish generating class-level masks for mask_validation_58.png.
# Finish generating class-level masks for mask_validation_59.png.
# Finish generating class-level masks for mask_validation_6.png.
# Finish generating class-level masks for mask_validation_60.png.
# Finish generating class-level masks for mask_validation_61.png.
# Finish generating class-level masks for mask_validation_62.png.
# Finish generating class-level masks for mask_validation_63.png.
# Finish generating class-level masks for mask_validation_64.png.
# Finish generating class-level masks for mask_validation_65.png.
# Finish generating class-level masks for mask_validation_66.png.
# Finish generating class-level masks for mask_validation_67.png.
# Finish generating class-level masks for mask_validation_68.png.
# Finish generating class-level masks for mask_validation_69.png.
# Finish generating class-level masks for mask_validation_7.png.
# Finish generating class-level masks for mask_validation_70.png.
# Finish generating class-level masks for mask_validation_71.png.
# Finish generating class-level masks for mask_validation_72.png.
# Finish generating class-level masks for mask_validation_73.png.
# Finish generating class-level masks for mask_validation_74.png.
# Finish generating class-level masks for mask_validation_75.png.
# Finish generating class-level masks for mask_validation_76.png.
# Finish generating class-level masks for mask_validation_77.png.
# Finish generating class-level masks for mask_validation_78.png.
# Finish generating class-level masks for mask_validation_79.png.
# Finish generating class-level masks for mask_validation_8.png.
# Finish generating class-level masks for mask_validation_80.png.
# Finish generating class-level masks for mask_validation_81.png.
# Finish generating class-level masks for mask_validation_82.png.
# Finish generating class-level masks for mask_validation_83.png.
# Finish generating class-level masks for mask_validation_84.png.
# Finish generating class-level masks for mask_validation_85.png.
# Finish generating class-level masks for mask_validation_86.png.
# Finish generating class-level masks for mask_validation_87.png.
# Finish generating class-level masks for mask_validation_88.png.
# Finish generating class-level masks for mask_validation_89.png.
# Finish generating class-level masks for mask_validation_9.png.
# Finish generating class-level masks for mask_validation_90.png.
# Finish generating class-level masks for mask_validation_91.png.
# Finish generating class-level masks for mask_validation_92.png.
# Finish generating class-level masks for mask_validation_93.png.
# Finish generating class-level masks for mask_validation_94.png.
# Finish generating class-level masks for mask_validation_95.png.
# Finish generating class-level masks for mask_validation_96.png.
# Finish generating class-level masks for mask_validation_97.png.
# Finish generating class-level masks for mask_validation_98.png.
# Finish generating class-level masks for mask_validation_99.png.

# %% [markdown]
# ## Generate HDF5 files

# %%
from sklearn.model_selection import train_test_split
from ml_core.preprocessing.patches_extraction import Extractor, crop_and_save_patches_to_hdf5
import re
from functools import reduce

# %%
def match_id_from_name(name, regex=r"\w+_(\d+).*\.png"):
    match = re.match(regex, name)
    if match:
        image_id = int(match[1])
    else:
        image_id = -1
    return image_id

# %%
def generate_train_test_paths(class_name):

# old verion: using sklearn for random split
#     image_paths = sorted(list((data_root).glob("collage_*.png")))
#     mask_paths = sorted(list((data_root / class_name).glob("mask_*.png")))

#     image_mask_pair = list(zip(image_paths, mask_paths))
#     train_pairs, test_pairs = train_test_split(image_mask_pair, test_size=0.2, random_state=42)
    
#     train_images, train_masks = debox_pairs(train_pairs)
#     test_images, test_masks = debox_pairs(test_pairs)
    train_images, train_masks, test_images, test_masks = [], [], [], []
    for dataset in ["train", "test"]:
        image_paths = {match_id_from_name(p.name): p for p in (data_root / dataset).glob("collage_*.png")}
        mask_paths = {match_id_from_name(p.name): p for p in (data_root / dataset / class_name).glob("mask_*.png")}
        
        for image_id in image_paths:
            if image_id != -1 and image_id in mask_paths:
                output_images, output_masks = (train_images, train_masks) if dataset == "train" \
                                                else (test_images, test_masks)
                
                output_images.append(image_paths[image_id])
                output_masks.append(mask_paths[image_id])
                
    assert reduce(lambda a,b: a & b, map(lambda x: len(x) != 0, (train_images, train_masks, test_images, test_masks))), \
            print(f"One of train/test images/masks is empty for class {class_name}.")
    
    return train_images, train_masks, test_images, test_masks

# %%
def debox_pairs(pairs):
    return [p[0] for p in pairs],  [p[1] for p in pairs]

# %%
def export_to_hdf5(output_root, train_images, train_masks, test_images, test_masks):
    extractor = Extractor(config_section_name=f"Collage_{class_name}")

    crop_and_save_patches_to_hdf5(output_root / f"HE_{class_name}_train.h5",
                                  images=train_images,
                                  masks=train_masks,
                                  extractor=extractor)
    
    crop_and_save_patches_to_hdf5(output_root / f"HE_{class_name}_val.h5",
                                  images=test_images,
                                  masks=test_masks,
                                  extractor=extractor)

# %%
data_root = Path("../../data/Collage")
output_root = Path("../../data/Collage/hdf5_data")

# %%
for class_name in ["Tubules", "Glomerulus", "Artery", "Arteriole"]:
    extractor = Extractor(config_section_name=f"Collage_{class_name}")

    for split in ("train", "val"):
        mask_root = data_root / f"ROI_data/{split}/{class_name}"
        roi_root = data_root / f"ROI_data/{split}/Raw"
        
        fpaths = list(mask_root.glob("mask_*.png"))
        roi_mask_mappings = {"roi": [], "mask": []}
        
        for fpath in fpaths:
            roi_name = fpath.name.replace("mask_", "collage_")
            roi_path = roi_root / roi_name
            if roi_path.exists():
                roi_mask_mappings["mask"].append(fpath)
                roi_mask_mappings["roi"].append(roi_path)
            else:
                print(f"ROI for {fpath} is not found.")
                    
        assert roi_mask_mappings
        
        hdf5_name = f"patch_{extractor.patch_size}/{class_name}_{split}.h5"
        output_path = output_root / hdf5_name
        if not output_path.parent.exists():
            output_path.parent.mkdir(parents=True, exist_ok=True)
        
        crop_and_save_patches_to_hdf5(output_root / hdf5_name,
                                      images=roi_mask_mappings["roi"],
                                      masks=roi_mask_mappings["mask"],
                                      extractor=extractor)
        
        print(f"Finish saving {hdf5_name}.")
# Out:
# Finish saving patch_256/Tubules_train.h5.
# Finish saving patch_256/Tubules_val.h5.
# Finish saving patch_256/Glomerulus_train.h5.
# Finish saving patch_256/Glomerulus_val.h5.
# Finish saving patch_256/Artery_train.h5.
# Finish saving patch_256/Artery_val.h5.
# Finish saving patch_256/Arteriole_train.h5.
# Finish saving patch_256/Arteriole_val.h5.
