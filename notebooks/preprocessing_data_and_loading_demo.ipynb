# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Download the small test dataset first

# %% [markdown]
# If working on Colab or you have gsutil installed on your local machine, try the code block below; otherwise, use the [link](https://storage.googleapis.com/kidney_dataset/collage.zip) to download the dataset and move it to `/tmp/test_data/` folder.

# %%
# !mkdir -p /tmp/test_data/
# !gsutil cp -n gs://kidney_dataset/collage.zip /tmp/test_data/
# Out:
# Skipping existing item: file:///tmp/test_data/collage.zip

# %%
# !unzip -o /tmp/test_data/collage.zip -d /tmp/test_data/
# Out:
# Archive:  /tmp/test_data/collage.zip
#   inflating: /tmp/test_data/hdf5_source/collage_2.png
#   inflating: /tmp/test_data/hdf5_source/collage_6.png
#   inflating: /tmp/test_data/hdf5_source/collage_8.png
#   inflating: /tmp/test_data/hdf5_source/collage_7.png
#   inflating: /tmp/test_data/hdf5_source/collage_1.png
#   inflating: /tmp/test_data/hdf5_source/collage_9.png
#   inflating: /tmp/test_data/hdf5_source/mask_7.png
#   inflating: /tmp/test_data/hdf5_source/collage_0.png
#   inflating: /tmp/test_data/hdf5_source/collage_4.png
#   inflating: /tmp/test_data/hdf5_source/mask_6.png
#   inflating: /tmp/test_data/hdf5_source/mask_3.png
#   inflating: /tmp/test_data/hdf5_source/mask_5.png
#   inflating: /tmp/test_data/hdf5_source/mask_2.png
#   inflating: /tmp/test_data/hdf5_source/mask_0.png
#   inflating: /tmp/test_data/hdf5_source/mask_9.png
#   inflating: /tmp/test_data/hdf5_source/collage_5.png
#   inflating: /tmp/test_data/hdf5_source/mask_1.png
#   inflating: /tmp/test_data/hdf5_source/mask_8.png
#   inflating: /tmp/test_data/hdf5_source/collage_3.png
#   inflating: /tmp/test_data/hdf5_source/mask_4.png

# %% [markdown]
# ## Create hdf5 dataset

# %%
from pathlib import Path

# %%
input_data_root = Path("/tmp/test_data/hdf5_source/")
output_data_root = Path("/tmp/test_data/hdf5_output")
output_data_root.mkdir(exist_ok=True)

# %%
from patches_extraction import extract_img_patches, extract_mask_patches, Extractor, crop_and_save_patches_to_hdf5

# %%
extractor = Extractor(resize=0.25, mirror_pad_size=128, patch_size=256, stride_size=64)

# %%
images = [p for p in input_data_root.glob("*.png") if "mask" not in str(p)]
images.sort()
images
# Out:
# [PosixPath('/tmp/test_data/hdf5_source/collage_0.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_1.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_2.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_3.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_4.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_5.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_6.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_7.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_8.png'),
#  PosixPath('/tmp/test_data/hdf5_source/collage_9.png')]

# %%
masks = [p for p in input_data_root.glob("*mask*.png")]
masks.sort()
masks
# Out:
# [PosixPath('/tmp/test_data/hdf5_source/mask_0.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_1.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_2.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_3.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_4.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_5.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_6.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_7.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_8.png'),
#  PosixPath('/tmp/test_data/hdf5_source/mask_9.png')]

# %%
hdf5_dataset_fname = output_data_root / "train.h5"
hdf5_dataset_fname
# Out:
# PosixPath('/tmp/test_data/hdf5_output/train.h5')

# %%
# test the function of image extraction helper function
patches, image_indices = extract_img_patches(images[0], extractor)
patches.shape, len(image_indices)
# Out:
# /home/henryhuang/.conda/envs/pytorch/lib/python3.7/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function extract_patches is deprecated; The function feature_extraction.image.extract_patches has been deprecated in 0.22 and will be removed in 0.24.
#   warnings.warn(msg, category=FutureWarning)
# ((144, 256, 256, 3), 144)

# %%
# test the function of mask extraction helper function
mask_patches, mask_indices = extract_mask_patches(masks[0],extractor)
mask_patches.shape, len(mask_indices)
# Out:
# ((144, 256, 256, 3), 144)

# %%
# test the main function used for generating hdf5 file
crop_and_save_patches_to_hdf5(hdf5_dataset_fname, images, masks, extractor)

# %%
# !ls $output_data_root
# Out:
# train.h5

# %% [markdown]
# ## Load data as torch Dataset and Dataloader

# %%
from dataset import Dataset
import torch
from torch.utils.data import DataLoader
import albumentations as A

# %%
# parameters for augmentations and training
patch_size = 256
device = torch.device("cuda:0")
edge_weight = 1.2

# %%
# do not apply any transformation related to data type casting, 
# e.g. toTenser() here. Also use albumentations Compose API instead of torchvision.
aug_transform = A.Compose([
    A.VerticalFlip(p=0.5),
    A.HorizontalFlip(p=0.5),
    A.OneOf([
        A.HueSaturationValue(),
        A.ToGray()
    ])
])

# %%
hdf5_dataset_fname = Path("/tmp/test_data/hdf5_output/train.h5")

# %%
dataset = Dataset(hdf5_dataset_fname, 
                  aug_transform=aug_transform,
                  use_edge_mask=True)

# %%
from dataset import visualize_one_sample

# %%
visualize_one_sample(dataset, 50, positive_only=True)
# Out:
# Sample 50 has the 50-th positive mask.

# %%
visualize_one_sample(dataset, 60, positive_only=False)

# %%
dataloader = DataLoader(dataset, batch_size=8, shuffle=True, num_workers=2, pin_memory=True)

# %% [markdown]
# ## Simulate the training procedure to test the functionality of dataloader

# %%
import sys
sys.path.append("..") # Adds higher directory to python modules path.

# %%
from training.unet import UNet
import torch.optim as optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
import torch.nn.functional as F
from tqdm.notebook import tqdm

# %%
unet = UNet(in_channels=3,
            n_classes=5,
            depth = 8,# this depth may need to be modified
            wf = 3,
            padding = True,
            batch_norm = True,
            up_mode = "upconv"
            ).to(device)

optimizer = torch.optim.Adam(params = unet.parameters(),lr = 1e-3)
scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience = 25, verbose = True)
criterion = torch.nn.CrossEntropyLoss(reduction="none")
EPOCH = 10

# %%
#tensorboard if necessary
from torch.utils.tensorboard import SummaryWriter
# %load_ext tensorboard

# %%
logs_base_dir = Path("/tmp/tf-log")
logs_base_dir.mkdir(exist_ok=True)
tb = SummaryWriter(logs_base_dir)

# %%
for i, data in enumerate(dataloader):
    img, mask, edge_mask = list(map(lambda x: x.to(device), data))
    if i == 0:
        list(map(lambda x: print(f"Shape: {x.shape}, Dtype: {x.dtype}"), data))

    unet.zero_grad()
    # generate a naive prediction using binary random samples
    output = unet(img)

    loss_matrix = criterion(output, mask)
    loss = (loss_matrix * (edge_weight**edge_mask)).mean()

    loss.backward()
    optimizer.step()

    loss_val = loss.detach().cpu().item()
    tb.add_scalar("loss", loss_val, i)
    print(f"Batch {i} has loss: {loss_val}")
# Out:
# Shape: torch.Size([8, 3, 256, 256]), Dtype: torch.float32
# Shape: torch.Size([8, 256, 256]), Dtype: torch.int64
# Shape: torch.Size([8, 256, 256]), Dtype: torch.float32
# Batch 0 has loss: 1.4745101839359803e+19
# Batch 1 has loss: 1.5279659104017056e+19
# Batch 2 has loss: 1.4547613058336817e+19
# Batch 3 has loss: 1.4372300327334445e+19
# Batch 4 has loss: 1.3942394579408912e+19
# Batch 5 has loss: 1.326824771653573e+19
# Batch 6 has loss: 1.3492221533648585e+19
# Batch 7 has loss: 1.3079968444906996e+19
# Batch 8 has loss: 1.2584834169663652e+19
# Batch 9 has loss: 1.2399887517778706e+19
# Batch 10 has loss: 1.2229027808868827e+19
# Batch 11 has loss: 1.2153032863691833e+19
# Batch 12 has loss: 1.1141208387742597e+19
# Batch 13 has loss: 1.1875851479887643e+19
# Batch 14 has loss: 1.1172493891599335e+19
# Batch 15 has loss: 1.0814842550293103e+19
# Batch 16 has loss: 1.1578978942341612e+19
# Batch 17 has loss: 1.0927704120349426e+19
# Batch 18 has loss: 9.73377303104979e+18
# Batch 19 has loss: 1.0126436121119293e+19
# Batch 20 has loss: 1.0023666968294326e+19
# Batch 21 has loss: 9.503331886542356e+18
# Batch 22 has loss: 9.691696920078057e+18
# Batch 23 has loss: 9.479262477498712e+18
# Batch 24 has loss: 9.182122758627131e+18
# Batch 25 has loss: 9.186563686091719e+18
# Batch 26 has loss: 9.073501455163326e+18
# Batch 27 has loss: 9.110188859647328e+18
# Batch 28 has loss: 9.343768560096248e+18
# Batch 29 has loss: 8.753094970736378e+18
# Batch 30 has loss: 9.038447375202386e+18
# Batch 31 has loss: 8.865142902188147e+18
# Batch 32 has loss: 8.875939556617093e+18
# Batch 33 has loss: 9.096023301590876e+18
# Batch 34 has loss: 9.600102103926178e+18
# Batch 35 has loss: 8.582450216349729e+18
# Batch 36 has loss: 8.583532685547274e+18
# Batch 37 has loss: 8.70887866038118e+18
# Batch 38 has loss: 8.642728742319292e+18
# Batch 39 has loss: 8.209932378324337e+18
# Batch 40 has loss: 8.241746747274035e+18
# Batch 41 has loss: 8.160495037004644e+18
# Batch 42 has loss: 7.850847823611298e+18
# Batch 43 has loss: 8.040274435623617e+18
# Batch 44 has loss: 8.134721934693761e+18
# Batch 45 has loss: 7.611277983814255e+18
# Batch 46 has loss: 8.23285774551928e+18
# Batch 47 has loss: 7.947819801378816e+18
# Batch 48 has loss: 7.773420764539126e+18
# Batch 49 has loss: 7.962061775493399e+18
# Batch 50 has loss: 7.470157865412461e+18
# Batch 51 has loss: 7.78085896070103e+18
# Batch 52 has loss: 7.892646307897016e+18
# Batch 53 has loss: 7.713236796569551e+18
# Batch 54 has loss: 7.621440220033974e+18
# Batch 55 has loss: 7.803088886791406e+18
# Batch 56 has loss: 7.793038251001905e+18
# Batch 57 has loss: 7.204948513967309e+18
# Batch 58 has loss: 7.887202076072083e+18
# Batch 59 has loss: 7.189891801736544e+18
# Batch 60 has loss: 7.580023816038908e+18
# Batch 61 has loss: 7.987681495932207e+18
# Batch 62 has loss: 7.95535970236629e+18
# Batch 63 has loss: 7.423294480813392e+18
# Batch 64 has loss: 7.363453560471683e+18
# Batch 65 has loss: 7.413544561454088e+18
# Batch 66 has loss: 6.743426858940891e+18
# Batch 67 has loss: 7.271753191203537e+18
# Batch 68 has loss: 6.787539265447264e+18
# Batch 69 has loss: 7.165680555692917e+18
# Batch 70 has loss: 7.071126403994878e+18
# Batch 71 has loss: 7.251898210229158e+18
# Batch 72 has loss: 7.005672476793373e+18
# Batch 73 has loss: 7.274442046889263e+18
# Batch 74 has loss: 6.963789879868129e+18
# Batch 75 has loss: 7.050333539602006e+18
# Batch 76 has loss: 7.301969969758077e+18
# Batch 77 has loss: 7.238274711405199e+18
# Batch 78 has loss: 7.370255139401105e+18
# Batch 79 has loss: 7.115031002803601e+18
# Batch 80 has loss: 6.973732763518108e+18
# Batch 81 has loss: 7.052473189229658e+18
# Batch 82 has loss: 6.490911918994227e+18
# Batch 83 has loss: 6.873226405623103e+18
# Batch 84 has loss: 6.674711780251402e+18
# Batch 85 has loss: 6.885879035679736e+18
# Batch 86 has loss: 6.766850854659031e+18
# Batch 87 has loss: 6.621245278571725e+18
# Batch 88 has loss: 6.809202943049335e+18
# Batch 89 has loss: 6.770580398100447e+18
# Batch 90 has loss: 7.105704945176805e+18
# Batch 91 has loss: 6.591189578470654e+18
# Batch 92 has loss: 6.660664419694936e+18
# Batch 93 has loss: 6.758224086427501e+18
# Batch 94 has loss: 6.926393840140026e+18
# Batch 95 has loss: 6.670037756321726e+18
# Batch 96 has loss: 6.598084615888437e+18
# Batch 97 has loss: 6.59993729298124e+18
# Batch 98 has loss: 6.85988493153167e+18
# Batch 99 has loss: 6.516044555781931e+18
# Batch 100 has loss: 6.985694350516683e+18
# Batch 101 has loss: 6.480793113483805e+18
# Batch 102 has loss: 6.507256159341117e+18
# Batch 103 has loss: 6.60265638523673e+18
# Batch 104 has loss: 6.174083795159876e+18
# Batch 105 has loss: 6.730085384849457e+18
# Batch 106 has loss: 6.628139766233694e+18
# Batch 107 has loss: 6.413816912433644e+18
# Batch 108 has loss: 6.989306246213927e+18
# Batch 109 has loss: 6.72122442064121e+18
# Batch 110 has loss: 6.864026791833502e+18
# Batch 111 has loss: 6.388729905378492e+18
# Batch 112 has loss: 6.749241076428571e+18
# Batch 113 has loss: 7.131857378999271e+18
# Batch 114 has loss: 6.625637277768876e+18
# Batch 115 has loss: 6.139278204826812e+18
# Batch 116 has loss: 6.323509074642076e+18
# Batch 117 has loss: 6.385600145530028e+18
# Batch 118 has loss: 6.332070971687567e+18
# Batch 119 has loss: 6.471512685589561e+18
# Batch 120 has loss: 6.482373661448733e+18
# Batch 121 has loss: 6.444157386046308e+18
# Batch 122 has loss: 6.218949916887089e+18
# Batch 123 has loss: 6.466243276113445e+18
# Batch 124 has loss: 6.487688150901588e+18
# Batch 125 has loss: 6.109058127737389e+18
# Batch 126 has loss: 6.524419535850701e+18
# Batch 127 has loss: 6.275900221159375e+18
# Batch 128 has loss: 6.166803378916557e+18
# Batch 129 has loss: 6.340819785709781e+18
# Batch 130 has loss: 6.231703702013477e+18
# Batch 131 has loss: 6.255706040847827e+18
# Batch 132 has loss: 6.423165510048809e+18
# Batch 133 has loss: 6.846746867091374e+18
# Batch 134 has loss: 6.725589481803481e+18
# Batch 135 has loss: 6.090296611076833e+18
# Batch 136 has loss: 6.216692619515265e+18
# Batch 137 has loss: 6.250282699743822e+18
# Batch 138 has loss: 6.181902972100805e+18
# Batch 139 has loss: 6.483026221599818e+18
# Batch 140 has loss: 6.183253172379714e+18
# Batch 141 has loss: 6.443141437302243e+18
# Batch 142 has loss: 6.478817840844505e+18
# Batch 143 has loss: 6.462640176509223e+18
# Batch 144 has loss: 6.057101255522648e+18
# Batch 145 has loss: 6.122311640898601e+18
# Batch 146 has loss: 6.116951521713193e+18
# Batch 147 has loss: 5.993625899495326e+18
# Batch 148 has loss: 5.970933628765471e+18
# Batch 149 has loss: 6.228767456211501e+18
# Batch 150 has loss: 6.33875105458212e+18
# Batch 151 has loss: 6.068106267405058e+18
# Batch 152 has loss: 6.186416467332825e+18
# Batch 153 has loss: 5.903866718006018e+18
# Batch 154 has loss: 6.0543838125346e+18
# Batch 155 has loss: 5.977791832543724e+18
# Batch 156 has loss: 5.94498130605926e+18
# Batch 157 has loss: 6.129838347746542e+18
# Batch 158 has loss: 6.110009755051229e+18
# Batch 159 has loss: 6.082007942670844e+18
# Batch 160 has loss: 6.101468198970851e+18
# Batch 161 has loss: 6.067120555230757e+18
# Batch 162 has loss: 5.703767696378692e+18
# Batch 163 has loss: 5.907424187877687e+18
# Batch 164 has loss: 5.91791352880667e+18
# Batch 165 has loss: 5.836749229711688e+18
# Batch 166 has loss: 5.83467665029333e+18
# Batch 167 has loss: 6.058426167034118e+18
# Batch 168 has loss: 6.15883741717332e+18
# Batch 169 has loss: 6.322482130781733e+18
# Batch 170 has loss: 5.872561972695794e+18
# Batch 171 has loss: 6.181285046565994e+18
# Batch 172 has loss: 5.887232756345209e+18
# Batch 173 has loss: 5.796741300111802e+18
# Batch 174 has loss: 5.793133252705255e+18
# Batch 175 has loss: 6.092323560762638e+18
# Batch 176 has loss: 5.882171704322556e+18
# Batch 177 has loss: 5.778408592986079e+18
# Batch 178 has loss: 5.470247919313486e+18
# Batch 179 has loss: 6.246536663627989e+18
